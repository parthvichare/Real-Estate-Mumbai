# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import numpy as np

# %%
# webpage=requests.get('https://www.magicbricks.com/ready-to-move-flats-in-mumbai-pppfs').text
# soup=BeautifulSoup(webpage,'html.parser')

# %%
url='https://www.magicbricks.com/ready-to-move-flats-in-mumbai-pppfs'
webpage=requests.get(url).text
soup=BeautifulSoup(webpage,'html.parser')

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Data to store in List
name = []
society_name = []
price = []
sqft = []
carpet_area = []
furnished_status = []
bathroom = []
bedrooms = []
floor = []
link = []
balcony=[]

for page_number in range(1,160):
    url = f'https://www.magicbricks.com/ready-to-move-flats-in-mumbai-pppfs?page={page_number}'

    try:
        webpage = requests.get(url).text
        soup = BeautifulSoup(webpage, 'html.parser')

        property_details = soup.find_all('div', class_='mb-srp__card')
        property_info = soup.find_all('div', class_='mb-srp__card__summary__list')

        for i, info in zip(property_details, property_info):
            name.append(i.find('h2').text.strip())
            
            # Extracting Property Details Link
            link_element = i.find('a', href=True)
            link.append(link_element['href'].strip() if link_element and 'href' in link_element.attrs else np.nan)

            society_element = i.find(class_='mb-srp__card__society--name')
            society_name.append(society_element.text.strip() if society_element else np.nan)
            
            price_element = i.find(class_='mb-srp__card__price--amount')
            sqft_element = i.find(class_='mb-srp__card__price--size')

            price.append(price_element.text.strip() if price_element else np.nan)
            sqft.append(sqft_element.text.strip() if sqft_element else np.nan)

            # Extracting Carpet Area
            carpet = info.find('div', class_='mb-srp__card__summary--label', text='Carpet Area')
            carpet_area_value = carpet.find_next('div', class_='mb-srp__card__summary--value').text.strip() if carpet else np.nan
            carpet_area.append(carpet_area_value)
            
            furnished_label = info.find('div', class_='mb-srp__card__summary--label', text='Furnishing')
            furnished_value = furnished_label.find_next('div', class_='mb-srp__card__summary--value').text.strip() if furnished_label else np.nan
            furnished_status.append(furnished_value)
            
            floor_label = info.find('div', class_='mb-srp__card__summary--label', text='Floor')
            floor_value = floor_label.find_next('div', class_='mb-srp__card__summary--value').text.strip() if floor_label else np.nan
            floor.append(floor_value)
            
            bathroom_label = info.find('div', class_='mb-srp__card__summary--label', text='Bathroom')
            bathroom_value = bathroom_label.find_next('div', class_='mb-srp__card__summary--value').text.strip() if bathroom_label else np.nan
            bathroom.append(bathroom_value)
            
            balcony_label = info.find('div', class_='mb-srp__card__summary--label', text='Balcony')
            balcony_value = balcony_label.find_next('div', class_='mb-srp__card__summary--value').text.strip() if balcony_label else np.nan
            balcony.append(balcony_value)


    except Exception as e:
        print(f"Error on page {page_number}: {str(e)}")

# Manipulating the string Sqft
df = pd.DataFrame({'Name': name,
                   'Link': link,
                   'Society': society_name, 
                   'Price': price, 'Sqft': sqft, 
                   'Carpet': carpet_area, 
                   'Furnished': furnished_status, 
                   'Floor': floor,
                   'balcony':balcony,
                   'bathroom':bathroom})
df['Sqft'] = df['Sqft'].apply(lambda x: x[0:15] if x is not np.nan else np.nan)
df['Bedroom'] = df['Name'].str.extract(r'(\d)')
df
# Out:
#                                                    Name  \
# 0     3 BHK Ready to Occupy Flat for sale in Girivan...
# 1      2 BHK Ready to Occupy Flat for sale Dahisar West
# 2      1 BHK Ready to Occupy Flat for sale Chembur East
# 3     2 BHK Ready to Occupy Flat for sale in Royal S...
# 4       2 BHK Ready to Occupy Flat for sale Bandra West
# ...                                                 ...
# 4765  3 BHK Ready to Occupy Flat for sale Kandivali ...
# 4766  2 BHK Ready to Occupy Flat for sale in Royal P...
# 4767  3 BHK Ready to Occupy Flat for sale in Nobel H...
# 4768     2 BHK Ready to Occupy Flat for sale Dadar West
# 4769  2 BHK Ready to Occupy Flat for sale in Imperia...
#
#                                                    Link  \
# 0     https://www.magicbricks.com/girivan-paramjyoti...
# 1                                                   NaN
# 2                                                   NaN
# 3     https://www.magicbricks.com/royal-sapphire-mal...
# 4                                                   NaN
# ...                                                 ...
# 4765                                                NaN
# 4766  https://www.magicbricks.com/royal-palms-diamon...
# 4767  https://www.magicbricks.com/nobel-house-chs-an...
# 4768                                                NaN
# 4769  https://www.magicbricks.com/imperial-classic-n...
#
#                                 Society     Price             Sqft     Carpet  \
# 0                    Girivan Paramjyoti  ₹3.10 Cr  ₹25833 per sqft   979 sqft
# 1                                   NaN  ₹1.85 Cr              NaN   707 sqft
# 2                                   NaN   ₹38 Lac  ₹13103 per sqft        NaN
# 3                        Royal Sapphire  ₹1.80 Cr  ₹16071 per sqft   625 sqft
# 4                                   NaN  ₹3.20 Cr  ₹40000 per sqft   560 sqft
# ...                                 ...       ...              ...        ...
# 4765                                NaN  ₹3.25 Cr  ₹25896 per sqft   950 sqft
# 4766  Royal Palms Diamond Isle Phase II   ₹72 Lac  ₹10000 per sqft   610 sqft
# 4767                    Nobel House CHS  ₹3.95 Cr  ₹32917 per sqft  1060 sqft
# 4768                                NaN  ₹3.40 Cr  ₹48571 per sqft   765 sqft
# 4769                   Imperial Classic   ₹85 Lac   ₹6296 per sqft  1000 sqft
#
#            Furnished        Floor balcony bathroom Bedroom
# 0     Semi-Furnished  6 out of 13       1        3       3
# 1        Unfurnished   3 out of 6     NaN        2       2
# 2          Furnished   1 out of 3     NaN        1       1
# 3     Semi-Furnished  7 out of 16     NaN        2       2
# 4     Semi-Furnished   1 out of 4       1        2       2
# ...              ...          ...     ...      ...     ...
# 4765  Semi-Furnished  2 out of 14     NaN        3       3
# 4766       Furnished  6 out of 20     NaN        2       2
# 4767       Furnished   3 out of 7       1        3       3
# 4768       Furnished   3 out of 7       3        2       2
# 4769       Furnished   5 out of 7       2        2       2
#
# [4770 rows x 11 columns]

# %%
df.sample(10)
# Out:
#                                                    Name  \
# 2303  2 BHK Ready to Occupy Flat for sale Santacruz ...
# 2227  1 BHK Ready to Occupy Flat for sale in Uttam H...
# 1591  2 BHK Ready to Occupy Flat for sale in Acme An...
# 3033  2 BHK Ready to Occupy Flat for sale in Royal S...
# 3852    3 BHK Ready to Occupy Flat for sale Mulund West
# 3876  1 BHK Ready to Occupy Flat for sale in Sapphir...
# 2257  2 BHK Ready to Occupy Flat for sale in Himalay...
# 3098  2 BHK Ready to Occupy Flat for sale in Lila Ap...
# 3865  3 BHK Ready to Occupy Flat for sale Kandivali ...
# 1459      2 BHK Ready to Occupy Flat for sale Bamanwada
#
#                                                    Link  \
# 2303                                                NaN
# 2227  https://www.magicbricks.com/uttam-heights-mala...
# 1591  https://www.magicbricks.com/acme-ankur-vile-pa...
# 3033  https://www.magicbricks.com/royal-sapphire-mal...
# 3852                                                NaN
# 3876  https://www.magicbricks.com/sapphire-lakeside-...
# 2257  https://www.magicbricks.com/himalaya-apartment...
# 3098  https://www.magicbricks.com/lila-apartment-gre...
# 3865                                                NaN
# 1459                                                NaN
#
#                                                 Society     Price  \
# 2303                                                NaN  ₹2.75 Cr
# 2227                                      Uttam Heights   ₹36 Lac
# 1591                                         Acme Ankur  ₹2.49 Cr
# 3033                                     Royal Sapphire  ₹1.80 Cr
# 3852                                                NaN  ₹3.70 Cr
# 3876                                  Sapphire Lakeside  ₹1.07 Cr
# 2257                                 Himalaya Apartment  ₹1.35 Cr
# 3098  Lila Apartment Green Park Co Op Housing Societ...  ₹3.65 Cr
# 3865                                                NaN  ₹3.25 Cr
# 1459                                                NaN  ₹1.40 Cr
#
#                  Sqft     Carpet       Furnished        Floor balcony  \
# 2303  ₹32353 per sqft        NaN     Unfurnished  5 out of 15     NaN
# 2227  ₹10000 per sqft        NaN  Semi-Furnished   1 out of 7       3
# 1591  ₹29294 per sqft   850 sqft  Semi-Furnished   2 out of 7       3
# 3033  ₹16071 per sqft   625 sqft  Semi-Furnished  7 out of 16     NaN
# 3852  ₹30204 per sqft        NaN     Unfurnished  9 out of 20       2
# 3876  ₹17120 per sqft   480 sqft  Semi-Furnished  3 out of 22     NaN
# 2257  ₹13500 per sqft   790 sqft       Furnished   1 out of 3     NaN
# 3098  ₹24333 per sqft  1240 sqft  Semi-Furnished   6 out of 6     NaN
# 3865  ₹25896 per sqft   950 sqft  Semi-Furnished  2 out of 14     NaN
# 1459              NaN   650 sqft     Unfurnished   1 out of 4       1
#
#      bathroom Bedroom
# 2303        2       2
# 2227        1       1
# 1591        2       2
# 3033        2       2
# 3852        3       3
# 3876        2       1
# 2257        2       2
# 3098        2       2
# 3865        3       3
# 1459        3       2

# %%
df.to_excel('Ready_to_move.xlsx', index=False)

# %%
#Facilities(Which Can Influenece Price)

urls = df['Link']
for url in urls:
    ammenities=[]
    if url and url != 'None':  # Check if the URL is not None or 'None'
        try:
            webpage = requests.get(url).text
            soup = BeautifulSoup(webpage, 'html.parser')
            
            # Now you can continue with your code to extract data from the page
            for i in soup.find_all('div',class_='amenities'):
                print(i.text.strip())
        except Exception as e:
            print(f"Error fetching or parsing data from {url}: {str(e)}")
    else:
        print("None")
# Out:
# Power Back Up
#
#
#
# Lift
#
#
#
# Security
#
#
#
# Park
#
#
#
# Reserved Parking
#
#
#
# Service/Goods Lift
#
#
#
# Visitor Parking
#
#
#
# Intercom Facility
#
#
#
# Bank & ATM
#
#
#
# Gymnasium
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Club House
# ★
#
#
#
# Power Back Up
#
#
#
# Swimming Pool
#
#
#
# Lift
#
#
#
# Security
#
#
#
# Park
#
#
#
# Reserved Parking
#
#
#
# Service/Goods Lift
#
#
#
# Visitor Parking
#
#
#
# Maintenance Staff
#
#
#
# Gymnasium
#
#
#
# Indoor Games Room
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Power Back Up
#
#
#
# Lift
#
#
#
# Security
#
#
#
# Reserved Parking
#
#
#
# Service/Goods Lift
#
#
#
# Visitor Parking
#
#
#
# Maintenance Staff
#
#
#
# DTH Television Facility
#
#
#
# Waste Disposal
#
#
#
# Fire Fighting Equipment
# Lift
#
#
#
# Security
#
#
#
# Park
#
#
#
# Reserved Parking
#
#
#
# Service/Goods Lift
#
#
#
# Visitor Parking
#
#
#
# Maintenance Staff
#
#
#
# Kids Club
#
#
#
# Retail Boulevard (Retail Shops)
#
#
#
# Water Storage
#
#
#
# Waste Disposal
#
#
#
# Fire Fighting Equipment
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Lift
#
#
#
# Security
#
#
#
# Reserved Parking
#
#
#
# Maintenance Staff
#
#
#
# Gymnasium
#
#
#
# Flower Gardens
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Club House
# ★
#
#
#
# Jogging and Strolling Track
# ★
#
#
#
# Barbeque Pit
# ★
#
#
#
# Power Back Up
#
#
#
# Swimming Pool
#
#
#
# Lift
#
#
#
# Security
#
#
#
# Park
#
#
#
# Reserved Parking
#
#
#
# Service/Goods Lift
#
#
#
# Visitor Parking
#
#
#
# Intercom Facility
# Club House
# ★
#
#
#
# Coffee Lounge & Restaurants
# ★
#
#
#
# Cafeteria/Food Court
# ★
#
#
#
# Jogging and Strolling Track
# ★
#
#
#
# Cycling & Jogging Track
# ★
#
#
#
# Dance Studio
# ★
#
#
#
# Power Back Up
#
#
#
# Swimming Pool
#
#
#
# Lift
#
#
#
# Security
#
#
#
# Park
#
#
#
# Reserved Parking
# Club House
# ★
#
#
#
# Jogging and Strolling Track
# ★
#
#
#
# Power Back Up
#
#
#
# Swimming Pool
#
#
#
# Lift
#
#
#
# Security
#
#
#
# Park
#
#
#
# Reserved Parking
#
#
#
# Service/Goods Lift
#
#
#
# Visitor Parking
#
#
#
# Maintenance Staff
#
#
#
# Bank & ATM
# Power Back Up
#
#
#
# Lift
#
#
#
# Security
#
#
#
# Reserved Parking
#
#
#
# Service/Goods Lift
#
#
#
# Visitor Parking
#
#
#
# Maintenance Staff
#
#
#
# DTH Television Facility
#
#
#
# Water Storage
#
#
#
# Waste Disposal
#
#
#
# Fire Fighting Equipment
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Club House
# ★
#
#
#
# Jogging and Strolling Track
# ★
#
#
#
# Outdoor Tennis Courts
# ★
#
#
#
# Private Terrace/Garden
# ★
#
#
#
# Power Back Up
#
#
#
# Swimming Pool
#
#
#
# Lift
#
#
#
# Security
#
#
#
# Park
#
#
#
# Reserved Parking
#
#
#
# Service/Goods Lift
#
#
#
# Visitor Parking
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Club House
# ★
#
#
#
# Power Back Up
#
#
#
# Swimming Pool
#
#
#
# Lift
#
#
#
# Security
#
#
#
# Reserved Parking
#
#
#
# Intercom Facility
#
#
#
# Maintenance Staff
#
#
#
# Guest Accommodation
#
#
#
# Gymnasium
#
#
#
# Flower Gardens
#
#
#
# Rain Water Harvesting
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Lift
#
#
#
# Security
#
#
#
# Reserved Parking
#
#
#
# Service/Goods Lift
#
#
#
# Visitor Parking
#
#
#
# Maintenance Staff
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?

# %%
false_count = (~df['Link'].isnull()).sum()
false_count
# Out:
# 19

# %%
df.isnull().sum()
# Out:
# Name          0
# Link         11
# Society      11
# Price         0
# Sqft          1
# Carpet        7
# Furnished     0
# Floor         0
# balcony      18
# bathroom      0
# Bedroom       1
# dtype: int64

# %%
url_amenities_list = []

urls = df['Link']
for url in urls:
    amenities = []
    if url and url != 'None':
        try:
            webpage = requests.get(url).text
            soup = BeautifulSoup(webpage, 'html.parser')
            
            # Extract amenities from the page
            for amenity in soup.find_all('div', class_='amenities'):
                amenities.append(amenity.text.strip())
            
            # Append the list of amenities to the main list
            url_amenities_list.append(amenities)
        except Exception as e:
            print(f"Error fetching or parsing data from {url}: {str(e)}")
    else:
        url_amenities_list.append([])  # Append an empty list if URL is None

# Now url_amenities_list contains a list of amenities for each URL
facilities=pd.DataFrame({'facilities':url_amenities_list})
# Out:
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error fetching or parsing data from nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?

# %%
df['facilities']=facilities
df['facilities']

# %%
facilities_list = df['facilities']

cleaned_facilities_list = []

for facilities in facilities_list:
    if isinstance(facilities, list):
        cleaned_facilities = [facility.replace('\n', '').strip() for facility in facilities if facility]
        cleaned_facilities_list.append(', '.join(cleaned_facilities))
    else:
        cleaned_facilities_list.append(None)

print(cleaned_facilities_list)
# Out:
# ['Power Back Up Lift Security Park Reserved Parking Service/Goods Lift Visitor Parking Intercom Facility Bank & ATM Gymnasium', 'Club House★ Power Back Up Swimming Pool Lift Security Park Reserved Parking Service/Goods Lift Visitor Parking Maintenance Staff Gymnasium Indoor Games Room', 'Power Back Up Lift Security Reserved Parking Service/Goods Lift Visitor Parking Maintenance Staff DTH Television Facility Waste Disposal Fire Fighting Equipment', '', 'Lift Security Park Reserved Parking Service/Goods Lift Visitor Parking Maintenance Staff Kids Club Retail Boulevard (Retail Shops) Water Storage Waste Disposal Fire Fighting Equipment', '', 'Lift Security Reserved Parking Maintenance Staff Gymnasium Flower Gardens', 'Club House★ Jogging and Strolling Track★ Barbeque Pit★ Power Back Up Swimming Pool Lift Security Park Reserved Parking Service/Goods Lift Visitor Parking Intercom Facility', 'Club House★ Coffee Lounge & Restaurants★ Cafeteria/Food Court★ Jogging and Strolling Track★ Cycling & Jogging Track★ Dance Studio★ Power Back Up Swimming Pool Lift Security Park Reserved Parking', 'Club House★ Jogging and Strolling Track★ Power Back Up Swimming Pool Lift Security Park Reserved Parking Service/Goods Lift Visitor Parking Maintenance Staff Bank & ATM', '', 'Power Back Up Lift Security Reserved Parking Service/Goods Lift Visitor Parking Maintenance Staff DTH Television Facility Water Storage Waste Disposal Fire Fighting Equipment', '', 'Club House★ Jogging and Strolling Track★ Outdoor Tennis Courts★ Private Terrace/Garden★ Power Back Up Swimming Pool Lift Security Park Reserved Parking Service/Goods Lift Visitor Parking', '', '', 'Club House★ Power Back Up Swimming Pool Lift Security Reserved Parking Intercom Facility Maintenance Staff Guest Accommodation Gymnasium Flower Gardens Rain Water Harvesting', 'Lift Security Reserved Parking Service/Goods Lift Visitor Parking Maintenance Staff', '', None, None, None, None, None, None, None, None, None, None, None]
