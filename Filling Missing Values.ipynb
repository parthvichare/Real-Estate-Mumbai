# %%
import pandas as pd
import numpy as np
# Out:
# C:\Users\ADMIN\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df=pd.read_excel('Feature_flats.xlsx')

# %%
#Filing Missing Value of the Buildup Area

# %%
one=df[df['bedroom']==1]['Buildup']
two=df[df['bedroom']==2]['Buildup']
three=df[df['bedroom']==3]['Buildup']

#Calculating avg mean
onebhk_mean=one.mean()
twobhk_mean=two.mean()
threebhk_mean=three.mean()

#Filling Missing rows with mean
one=one.fillna(onebhk_mean)
two=two.fillna(twobhk_mean)
three=three.fillna(twobhk_mean)

# concat all the missing values in the buildup Column
df['Buildup']=pd.concat([one,two,three])

# %%
#Filling Missing Value of the SuperBuild Area

# %%
one=df[df['bedroom']==1]['SuperBuild_area']
two=df[df['bedroom']==2]['SuperBuild_area']
three=df[df['bedroom']==3]['SuperBuild_area']

#Calculating avg mean
onebhk_mean=one.mean()
twobhk_mean=two.mean()
threebhk_mean=three.mean()

#Filling Missing rows with mean
one=one.fillna(onebhk_mean)
two=two.fillna(twobhk_mean)
three=three.fillna(twobhk_mean)

# concat all the missing values in the buildup Column
df['SuperBuild_area']=pd.concat([one,two,three])

# %%
df
# Out:
#                                                    name  price  \
# 0      1 BHK Ready to Occupy Flat for sale Chembur East   0.38
# 1     1 BHK Ready to Occupy Flat for sale in Sapphir...   1.07
# 2     1 BHK Ready to Occupy Flat for sale in Royal P...   0.45
# 3     1 BHK Ready to Occupy Flat for sale in Poonam ...   2.25
# 4                  Studio Apartment for sale Virar West   0.15
# ...                                                 ...    ...
# 3265  3 BHK Ready to Occupy Flat for sale in Silver ...   4.15
# 3266  3 BHK Ready to Occupy Flat for sale in Lodha A...   6.80
# 3267  3 BHK Ready to Occupy Flat for sale in Sneha V...   2.30
# 3268  3 BHK Ready to Occupy Flat for sale in Premier...   2.10
# 3269  3 BHK Ready to Occupy Flat for sale in Ratan S...   1.99
#
#       price_per_sqft    area       furnished  floor  balcony  bathroom  \
# 0            13103.0     NaN       Furnished      1        1       1.0
# ...

# %%
df=df.rename(columns={'area':'carpet_area','Buildup':'buildup','SuperBuild_area':'superbuild_area'})

# %%
df_1=pd.read_csv('gurgaon_properties_cleaned_v1.csv')

# %%
# Feature for Additional Rooms Common Rooms(StoreRoom, pooja room, studyroom,serventroom)

# %%
df_1=pd.read_csv('gurgaon_properties_cleaned_v1.csv')
one_additional=df_1[df_1['bedRoom']==1]['additionalRoom'].max()
two_additional=df_1[df_1['bedRoom']==2]['additionalRoom'].max()
three_additional=df_1[df_1['bedRoom']==3]['additionalRoom'].max()
# df_1
# 1Bhk additional room is study room
# 2Bhk additional room is study room,servant room,store room
# 3bhk additional room is  study room, store room

# %%
df.head()
# Out:
#                                                 name  price  price_per_sqft  \
# 0   1 BHK Ready to Occupy Flat for sale Chembur East   0.38         13103.0
# 1  1 BHK Ready to Occupy Flat for sale in Sapphir...   1.07         17120.0
# 2  1 BHK Ready to Occupy Flat for sale in Royal P...   0.45          5294.0
# 3  1 BHK Ready to Occupy Flat for sale in Poonam ...   2.25         37500.0
# 4               Studio Apartment for sale Virar West   0.15          4480.0
#
#    carpet_area       furnished  floor  balcony  bathroom  bedroom  \
# 0          NaN       Furnished      1        1       1.0        1
# 1        480.0  Semi-Furnished      3        1       2.0        1
# 2        600.0     Unfurnished      1        3       1.0        1
# 3        550.0  Semi-Furnished      4        1       2.0        1
# 4          NaN     Unfurnished      3        1       1.0        1
#
#           society  buildup  superbuild_area
# 0    Chembur East    488.0            551.0
# ...

# %%
#Features Section
df['features']=df_1['features']
df.head(10)
# Out:
#                                                 name  price  price_per_sqft  \
# 0   1 BHK Ready to Occupy Flat for sale Chembur East   0.38         13103.0
# 1  1 BHK Ready to Occupy Flat for sale in Sapphir...   1.07         17120.0
# 2  1 BHK Ready to Occupy Flat for sale in Royal P...   0.45          5294.0
# 3  1 BHK Ready to Occupy Flat for sale in Poonam ...   2.25         37500.0
# 4               Studio Apartment for sale Virar West   0.15          4480.0
# 5  1 BHK Ready to Occupy Flat for sale Versova An...   0.23          6216.0
# 6  1 BHK Ready to Occupy Flat for sale in Chandak...   0.92         16673.0
# 7     1 BHK Ready to Occupy Flat for sale Ghodbunder   0.65         10109.0
# 8  1 BHK Ready to Occupy Flat for sale Tilak Naga...   0.84         25846.0
# 9  1 BHK Ready to Occupy Flat for sale in Panchsh...   1.10         14667.0
#
#    carpet_area       furnished  floor  balcony  bathroom  bedroom  \
# ...

# %%
#Unfurnished
df_1['furnishDetails'].iloc[2077]
# Out:
# "['1 Light', 'No AC', 'No Bed', 'No Chimney', 'No Curtains', 'No Dining Table', 'No Exhaust Fan', 'No Fan', 'No Geyser', 'No Modular Kitchen', 'No Microwave', 'No Fridge', 'No Sofa', 'No Stove', 'No TV', 'No Wardrobe', 'No Washing Machine', 'No Water Purifier']"

# %%
#Semi Furnished
df_1['furnishDetails'].iloc[2032]
# Out:
# "['1 Fan', '1 Light', '1 AC', 'No Bed', 'No Chimney', 'No Curtains', 'No Dining Table', 'No Exhaust Fan', 'No Geyser', 'No Modular Kitchen', 'No Microwave', 'No Fridge', 'No Sofa', 'No Stove', 'No TV', 'No Wardrobe', 'No Washing Machine', 'No Water Purifier']"

# %%
#Furnished
df_1['furnishDetails'].iloc[3379]
# Out:
# "['4 Wardrobe', '1 Water Purifier', '6 Fan', '1 Exhaust Fan', '4 Geyser', '10 Light', '6 AC', '1 Modular Kitchen', '1 Curtains', 'No Bed', 'No Chimney', 'No Dining Table', 'No Microwave', 'No Fridge', 'No Sofa', 'No Stove', 'No TV', 'No Washing Machine']"

# %%
#Replacing all Categorical Value with furnished_details

furnished = df[df['furnished'] == 'Furnished']
semi_furnished = df[df['furnished'] == 'Semi-Furnished']
unfurnished = df[df['furnished'] == 'Unfurnished']

furnished=furnished['furnished'].replace('Furnished',"['4 Wardrobe', '1 Water Purifier', '6 Fan', '1 Exhaust Fan', '4 Geyser', '10 Light', '6 AC', '1 Modular Kitchen', '1 Curtains', 'No Bed', 'No Chimney', 'No Dining Table', 'No Microwave', 'No Fridge', 'No Sofa', 'No Stove', 'No TV', 'No Washing Machine']")
semi_furnished=semi_furnished['furnished'].replace('Semi-Furnished', "['1 Fan', '1 Light', '1 AC', 'No Bed', 'No Chimney', 'No Curtains', 'No Dining Table', 'No Exhaust Fan', 'No Geyser', 'No Modular Kitchen', 'No Microwave', 'No Fridge', 'No Sofa', 'No Stove', 'No TV', 'No Wardrobe', 'No Washing Machine', 'No Water Purifier']")
unfurnished=unfurnished['furnished'].replace('Unfurnished',"['1 Light', 'No AC', 'No Bed', 'No Chimney', 'No Curtains', 'No Dining Table', 'No Exhaust Fan', 'No Fan', 'No Geyser', 'No Modular Kitchen', 'No Microwave', 'No Fridge', 'No Sofa', 'No Stove', 'No TV', 'No Wardrobe', 'No Washing Machine', 'No Water Purifier']")

df['furnished']=pd.concat([furnished,semi_furnished,unfurnished])

# %%
df.columns
# Out:
# Index(['name', 'price', 'price_per_sqft', 'carpet_area', 'furnished', 'floor',
#        'balcony', 'bathroom', 'bedroom', 'society', 'buildup',
#        'superbuild_area', 'features'],
#       dtype='object')

# %%
df.to_excel('flats_cleaned2.xlsx',index=False)

# %%
df.head(3)
# Out:
#                                                 name  price  price_per_sqft  \
# 0   1 BHK Ready to Occupy Flat for sale Chembur East   0.38         13103.0
# 1  1 BHK Ready to Occupy Flat for sale in Sapphir...   1.07         17120.0
# 2  1 BHK Ready to Occupy Flat for sale in Royal P...   0.45          5294.0
#
#    carpet_area                                          furnished  floor  \
# 0          NaN  ['4 Wardrobe', '1 Water Purifier', '6 Fan', '1...      1
# 1        480.0  ['1 Fan', '1 Light', '1 AC', 'No Bed', 'No Chi...      3
# 2        600.0  ['1 Light', 'No AC', 'No Bed', 'No Chimney', '...      1
#
#    balcony  bathroom  bedroom         society  buildup  superbuild_area  \
# 0        1       1.0        1    Chembur East    488.0            551.0
# 1        1       2.0        1  Lakeside Powai    490.0            547.0
# 2        3       1.0        1     Nala Sopara    504.0            535.0
#
#                                             features
# ...

# %%
df_2=pd.read_csv('gurgaon_properties_cleaned_v2.csv')
df_2.head(3)
# Out:
#   property_type                  society     sector  price  price_per_sqft  \
# 0          flat  signature global park 4  sector 36   0.82          7585.0
# 1          flat         smart world gems  sector 89   0.95          8600.0
# 2          flat            pyramid elite  sector 86   0.46            79.0
#
#       area                                       areaWithType  bedRoom  \
# 0   1081.0  Super Built up area 1081(100.43 sq.m.)Carpet a...        3
# 1   1105.0                   Carpet area: 1103 (102.47 sq.m.)        2
# 2  58228.0                 Carpet area: 58141 (5401.48 sq.m.)        2
#
#    bathroom balcony  ...  super_built_up_area built_up_area carpet_area  \
# 0         2       2  ...               1081.0           NaN       650.0
# 1         2       2  ...                  NaN           NaN      1103.0
# 2         2       1  ...                  NaN           NaN     58141.0
#
#    study room  servant room  store room  pooja room  others  furnishing_type  \
# ...

# %%
df_2.describe()
# Out:
#              price  price_per_sqft           area      bedRoom     bathroom  \
# count  3785.000000     3785.000000    3785.000000  3803.000000  3803.000000
# mean      2.505804    13800.167768    2845.999472     3.338154     3.405469
# std       2.950121    23052.005585   22783.349053     1.876734     1.930456
# min       0.070000        4.000000      50.000000     1.000000     1.000000
# 25%       0.940000     6808.000000    1220.000000     2.000000     2.000000
# 50%       1.500000     9000.000000    1725.000000     3.000000     3.000000
# 75%       2.700000    13765.000000    2295.000000     4.000000     4.000000
# max      31.500000   600000.000000  875000.000000    21.000000    21.000000
#
#           floorNum  super_built_up_area  built_up_area    carpet_area  \
# count  3784.000000          1915.000000    1733.000000    1944.000000
# mean      6.810254          1921.658251    2360.241413    2483.466943
# std       6.027555           767.160169   17719.603378   22375.239293
# ...

# %%
# Feature for Additional Rooms Common Rooms(StoreRoom, pooja room, studyroom,serventroom)
#Adding additionalRoom into my data for featuring
df['additionalRoom']=df_1['additionalRoom']

# %%
df.head(2)
# Out:
#                                                 name  price  price_per_sqft  \
# 0   1 BHK Ready to Occupy Flat for sale Chembur East   0.38         13103.0
# 1  1 BHK Ready to Occupy Flat for sale in Sapphir...   1.07         17120.0
#
#    carpet_area                                          furnished  floor  \
# 0          NaN  ['4 Wardrobe', '1 Water Purifier', '6 Fan', '1...      1
# 1        480.0  ['1 Fan', '1 Light', '1 AC', 'No Bed', 'No Chi...      3
#
#    balcony  bathroom  bedroom         society  buildup  superbuild_area  \
# 0        1       1.0        1    Chembur East    488.0            551.0
# 1        1       2.0        1  Lakeside Powai    490.0            547.0
#
#                                             features           additionalRoom
# 0                                ['Lift(s)', 'Park']            not available
# 1  ['Power Back-up', 'Intercom Facility', 'Lift(s...  study room,servant room

# %%
df_1[df_1['bedRoom']==1]['additionalRoom'].max()
#1bhk Additionalroom(study room)

df_1[df_1['bedRoom']==2]['additionalRoom'].max()
#2bhk Additionalroom(study room,pooja room)

df_1[df_1['bedRoom']==3]['additionalRoom'].max()
#3bhk Additionalroom(study room,storeroom,poojaroom)
# Out:
# 'study room,store room'

# %%
one=df[df['bedroom']==1]['additionalRoom']
one=one.replace('not available','pooja room').replace('servant room,others','others')

two=df[df['bedroom']==2]['additionalRoom'].loc[1421:2702]
two=two.replace('not available','study room,pooja room')

three=df[df['bedroom']==3]['additionalRoom']
three=three.replace('study room','study room,store room,pooja room').replace('servant room','pooja room,store room,servant room')

# %%
df['additionalRoom']=pd.concat([one,two,three],axis=0)

# %%
df['additionalRoom'].value_counts()
# Out:
# additionalRoom
# pooja room                                       749
# study room,pooja room                            532
# servant room                                     515
# not available                                    243
# others                                           209
#                                                 ...
# servant room,pooja room,study room                 1
# store room,study room                              1
# store room,pooja room,study room                   1
# others,study room                                  1
# store room,pooja room,servant room,study room      1
# Name: count, Length: 65, dtype: int64

# %%
#Additional room
#List of new columns to be created
# One-hot Encoding to True and False (1,0)

new_cols=['study room','servant room','store room','pooja room','others']
 
#Populate the new_col based on 'additionalRoom' column
for col in new_cols:
    df[col]=df['additionalRoom'].str.contains(col).astype(int)
df.sample(5)
# Out:
#                                                    name  price  \
# 1828     2 BHK Ready to Occupy Flat for sale Malad East   1.80
# 2009     2 BHK Ready to Occupy Flat for sale Malad West   1.85
# 524   1 BHK Ready to Occupy Flat for sale in Shri Ga...   0.65
# 948           1 BHK Ready to Occupy Flat for sale Tunga   1.05
# 1947  2 BHK Ready to Occupy Flat for sale in Galaxy ...   1.05
#
#       price_per_sqft  carpet_area  \
# 1828         18947.0        765.0
# 2009         21765.0        641.0
# 524          13684.0        430.0
# 948          17500.0        450.0
# 1947         11413.0        650.0
#
#                                               furnished  floor  balcony  \
# 1828  ['1 Light', 'No AC', 'No Bed', 'No Chimney', '...      3        1
# 2009  ['1 Light', 'No AC', 'No Bed', 'No Chimney', '...      8        1
# 524   ['1 Fan', '1 Light', '1 AC', 'No Bed', 'No Chi...      5        1
# 948   ['4 Wardrobe', '1 Water Purifier', '6 Fan', '1...      2        1
# ...

# %%
df['additionalRoom'].isnull().sum()
# Out:
# 0

# %%
#Featuring Furnish Details in the category of Semi-furnished,furnished,Unfurnished

# %%
df['furnished'].isnull().sum()
# Out:
# 45

# %%
df['furnished'][0]
# Out:
# "['4 Wardrobe', '1 Water Purifier', '6 Fan', '1 Exhaust Fan', '4 Geyser', '10 Light', '6 AC', '1 Modular Kitchen', '1 Curtains', 'No Bed', 'No Chimney', 'No Dining Table', 'No Microwave', 'No Fridge', 'No Sofa', 'No Stove', 'No TV', 'No Washing Machine']"

# %%
all_furnishings = []
for detail in df['furnished'].dropna():
    furnishings = detail.replace('[', '').replace(']', '').replace("'", "").split(', ')
    all_furnishings.extend(furnishings)
unique_furnishings = list(set(all_furnishings))
unique_furnishings
# Out:
# ['No Washing Machine',
#  '10 Light',
#  'No Geyser',
#  '1 Curtains',
#  'No Stove',
#  '4 Geyser',
#  '1 Fan',
#  'No Fan',
#  '4 Wardrobe',
#  'No Microwave',
#  'No TV',
#  '1 Light',
#  'No Exhaust Fan',
#  'No Modular Kitchen',
#  'No Bed',
#  '1 Water Purifier',
#  '1 Modular Kitchen',
#  '6 Fan',
#  '6 AC',
#  'No Chimney',
#  '1 AC',
#  '1 Exhaust Fan',
#  'No Sofa',
#  'No Water Purifier',
#  'No Fridge',
#  'No Curtains',
#  'No AC',
#  'No Wardrobe',
#  'No Dining Table']

# %%
furnishings_df

# %%
a=df['society'].value_counts()

# %%
a.sample(50)
# Out:
# society
# sale Chembur              11
# Chembur Colony             1
# move Mumbai                1
# Vasant Virar               1
# Bane Compound              2
# Mahim West                 8
# society Mumbai             1
# Sen Nagar                  1
# Arch Tardeo                1
# Pushpa Park                2
# Patil Galli                1
# Sagar Colony               2
# Mira Road                 30
# House Powai                2
# Kunj Virar                 1
# Gardens Mumbai             4
# Aria Parel                 1
# Road East                 25
# CHS Prabhadevi             1
# Apartment Mamledarwadi     2
# Govind Nagar               3
# Tara Road                  2
# Vati Powai                 2
# Ashokvan Mumbai            1
# Lane Mumbai                1
# sale Mahim                 1
# Enclave Nahur              2
# Antariksha Prabhadevi      2
# sale Kalina                3
# Lashkaria Empress          1
# Road Mumbai                6
# ...
