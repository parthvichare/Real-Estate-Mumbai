# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
# Out:
# C:\Users\ADMIN\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
import pandas as pd

flats=pd.read_excel('Ready_to_move.xlsx')

# %%
feature=flats[flats['Link'].notna()][0:600]

# %%
feature['Link']
# Out:
# 0      https://www.magicbricks.com/girivan-paramjyoti...
# 3      https://www.magicbricks.com/royal-sapphire-mal...
# 5      https://www.magicbricks.com/dheeraj-valley-tow...
# 6      https://www.magicbricks.com/sapphire-lakeside-...
# 7      https://www.magicbricks.com/royal-plaza-nalaso...
#                              ...
# 309    https://www.magicbricks.com/evershine-city-vas...
# 311    https://www.magicbricks.com/minar-tower-chs-jo...
# 312    https://www.magicbricks.com/poonam-enclave-gor...
# 314    https://www.magicbricks.com/swayam-apartment-m...
# 315    https://www.magicbricks.com/mathews-mansion-da...
# Name: Link, Length: 200, dtype: object

# %%
address_list=[]
for url in feature['Link']:
    addres = []
    try:
        webpage = requests.get(url).text
        soup = BeautifulSoup(webpage, 'html.parser')
        for i in soup.find_all(class_='proj-info__value'):
            addres.append(i.text.strip())
        address_list.append(addres)
        
    except Exception as e:
        print(f"Error fetching or parsing data from {url}: {str(e)}")

# Now url_amenities_list contains a list of amenities for each non-null URL
df = pd.DataFrame({'Address': address_list})

# %%
df
# Out:
#     Address
# 0        []
# 1        []
# 2        []
# 3        []
# 4        []
# ..      ...
# 195      []
# 196      []
# 197      []
# 198      []
# 199      []
#
# [200 rows x 1 columns]

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

address_list = []
pincode_list = []  # Changed the variable name to pincode_list

for url in feature['Link']:
    try:
        webpage = requests.get(url).text
        soup = BeautifulSoup(webpage, 'html.parser')
        property_details = soup.find_all('div', class_='proj-info__data')
        
        for i in property_details:
            address_element = i.find(class_='proj-info__data__value')
            address_list.append(address_element.text.strip() if address_element else np.nan)
            
    except Exception as e:
        print(f"Error on page {url}: {str(e)}")

df = pd.DataFrame({'address': address_list})  # Use pincode_list in DataFrame

# %%
df['address']

# %%
address_list = []
pincode_list = []  # Changed the variable name to pincode_list

for url in feature['Link']:
    webpage = requests.get(url).text
    soup = BeautifulSoup(webpage, 'html.parser')
    property_details = soup.find_all('div', class_='proj-info__data')
    property_details

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

address_list = []
pincode_list = []
towers=[]

for url in feature['Link']:
    try:
        webpage = requests.get(url).text
        soup = BeautifulSoup(webpage, 'html.parser')
        property_details = soup.find_all('div', class_='proj-info__data__block')

        address = None
        pincode = None

#Get the Idea of Html Structure
        for detail in property_details:
            title = detail.find('div', class_='proj-info__data__title')
            value = detail.find('div', class_='proj-info__data__value')
#             value_1=detail.find('div', class_='proj-info__data__value')

            if title and value:
                if title.text == 'Address':
                    address = value.text.strip()
                elif title.text == 'Pincode':
                    pincode = value.text.strip()

        # Append the data to the appropriate lists
        address_list.append(address)
        pincode_list.append(pincode)

    except Exception as e:
        print(f"Error processing {url}: {e}")

# Create a DataFrame if needed
df = pd.DataFrame({'Address': address_list, 'Pincode': pincode_list})
print(df)

# %%
df
# Out:
#                                                Address Pincode
# 0                                     Chembur, Mumbai.  400071
# 1    Dominic Lend 3, Marve Road, Opp LA Classique H...  400095
# 2    Near To Sai Baba Complex , Mohan Gokhale Marg ...  400065
# 3                                                 None  400076
# 4    Behind Yashwant Gaurav Complex, Nalasopara Wes...  401203
# ..                                                 ...     ...
# 195                                Vasai East, Mumbai.  401202
# 196  Momin Nagar, Jogeshwari West, Mumbai, Maharash...  400047
# 197  poonam enclave , film city road , goregaon eas...  400065
# 198  Mira Road East Near Beverly Park Mira Bhayanda...  401107
# 199                                               None  400092
#
# [200 rows x 2 columns]

# %%
address_list = []
pincode_list = []  # Corrected variable name for pincode list

for url in feature['Link']:
    try:
        webpage = requests.get(url).text
        soup = BeautifulSoup(webpage, 'html.parser')
        property_details = soup.find_all('div', class_='proj-info__data')
        property_functions = soup.find_all('div', class_='sub-wrap')
        
        for i, info in zip(property_details, property_functions):  # Use a different variable name for the second loop
            address_element = i.find(class_='proj-info__data__value')
            address_list.append(address_element.text.strip() if address_element else np.nan)
            
            pincode_label = info.find('div', class_='proj-info__data__label', text='Pincode')
            pincode_value = pincode_label.find_next('div', class_='proj-info__data__value').text.strip() if pincode_label else np.nan
            pincode_list.append(pincode_value)
            
    except Exception as e:
        print(f"Error on page {url}: {str(e)}")

df = pd.DataFrame({'address': address_list, 'Pincode': pincode_list})
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_5028\2771828750.py:15: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   pincode_label = info.find('div', class_='proj-info__data__label', text='Pincode')

# %%
address_list = []
pincode_list = []  # Corrected variable name for pincode list

for url in feature['Link']:
    try:
        webpage = requests.get(url).text
        soup = BeautifulSoup(webpage, 'html.parser')
        property_details = soup.find_all('div', class_='proj-info__data')
        property_functions = soup.find_all('div', class_='sub-wrap')
        
        for address, pincode_element in zip(property_details, property_functions):  # Different variable name for the second loop
            address_element = address.find(class_='proj-info__data__value')
            address_list.append(address_element.text.strip() if address_element else np.nan)
            
            pincode_element = pincode_element.find(class_='proj-info__data__value')  # Corrected class for pincode
            pincode_list.append(pincode_element.text.strip() if pincode_element else np.nan)
            
    except Exception as e:
        print(f"Error on page {url}: {str(e)}")

df = pd.DataFrame({'address': address_list, 'Pincode': pincode_list})

# %%
df
# Out:
#                                              address  Pincode
# 0                                   Chembur, Mumbai.      NaN
# 1  Dominic Lend 3, Marve Road, Opp LA Classique H...      NaN
# 2  Near To Sai Baba Complex , Mohan Gokhale Marg ...      NaN
# 3                                      Ready To Move      NaN
# 4  Behind Yashwant Gaurav Complex, Nalasopara Wes...      NaN
# 5    Plot bearing C.S. No. 6, H. No. 3, CTS No. 1223      NaN
# 6  Behind Narayan udyog bhavan, Industrial estate...      NaN
# 7  The View Godrej Hiranadani Link Rd, Near Kaila...      NaN
# 8  shop no 127 bldg no 17 Avenue M, Rustomjee Glo...      NaN
# 9  Challenger Towers Housing society, Kanakiya, T...      NaN

# %%
address_list=[]
for url in feature['Link']:
    try:
        webpage = requests.get(url).text
        soup = BeautifulSoup(webpage, 'html.parser')
        property_details=soup.find_all('div',class_='proj-info__data')
        
        for i in property_details:
            address_element=i.find(class_='proj-info__data__value')
            address_list.append(address_element.text.strip() if address_element else np.nan)
            
    except Exception as e:
        print(f"Error on page {url}: {str(e)}")
df = pd.DataFrame({'address': address_list})

# %%
# Out:
#                                              address
# 0                                   Chembur, Mumbai.
# 1  Dominic Lend 3, Marve Road, Opp LA Classique H...
# 2  Near To Sai Baba Complex , Mohan Gokhale Marg ...
# 3                                      Ready To Move
# 4  Behind Yashwant Gaurav Complex, Nalasopara Wes...
# 5    Plot bearing C.S. No. 6, H. No. 3, CTS No. 1223
# 6  Behind Narayan udyog bhavan, Industrial estate...
# 7  The View Godrej Hiranadani Link Rd, Near Kaila...
# 8  shop no 127 bldg no 17 Avenue M, Rustomjee Glo...
# 9  Challenger Towers Housing society, Kanakiya, T...
